# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/air_quality_no2.csv', index_col=0, 
    parse_dates=True)

# %%
df.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# ## Plots

# %%
df.plot.scatter(x="station_london", y="station_paris", alpha=0.5,
    figsize=(5, 5))

# %%
df.plot.box()
# Out:
# /Users/dsurrao/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
df.plot.area(figsize=(12, 4), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8c19d29d90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c19cc37d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c19d0c190>],
#       dtype=object)

# %%
df.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# ### Derived column

# %%
# create a derived column
df["london_mg_per_cubic"] = df["station_london"] * 1.882

# %%
df.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# 2019-05-07 04:00:00               35.758
# 2019-05-07 05:00:00               30.112
# 2019-05-07 06:00:00                  NaN

# %%
df.mean()
# Out:
# station_antwerp        25.778947
# station_paris          27.740538
# station_london         24.777090
# london_mg_per_cubic    46.630483
# dtype: float64

# %%
type(df['station_antwerp'])
# Out:
# pandas.core.series.Series
