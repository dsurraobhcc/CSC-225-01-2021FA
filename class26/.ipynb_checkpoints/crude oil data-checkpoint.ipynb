# %%
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt

# %%
crude_oil_data = pd.read_csv('data/U.S._crude_oil_production.csv')
crude_oil_data.head()

# %%
crude_oil_data['Arizona'].sum()

# %%
crude_oil_data['Virginia'].sum()

# %%
crude_oil_data.drop(['Arizona', 'Virginia'], inplace=True, axis = 1)

# %%
crude_oil_data.tail(10)
# Out:
#          Month  U.S. Crude Oil   Alabama  Alaska  Arkansas  California  \
# 111   9/1/2017             9495       18     482        14         469
# 112  10/1/2017             9703       18     507        14         469
# 113  11/1/2017            10103       18     510        14         468
# 114  12/1/2017            10040       17     512        14         461
# 115   1/1/2018             9995       16     508        14         463
# 116   2/1/2018            10248       17     513        14         463
# 117   3/1/2018            10461       17     512        14         462
# 118   4/1/2018            10475       17     497        14         465
# 119   5/1/2018            10443       16     496        14         464
# 120   6/1/2018            10674       16     451        14         462
#
#      Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# 111       399                                       1693
# 112       409                                       1477
# 113       421                                       1689
# 114       436                                       1576
# 115       436                                       1631
# 116       428                                       1704
# 117       428                                       1681
# 118       447                                       1583
# 119       447                                       1504
# 120       423                                       1658
#
#      Federal Offshore Pacific Crude Oil  Florida  ...  North Dakota  Ohio  \
# 111                                  15        4  ...          1096    56
# 112                                  15        5  ...          1184    54
# 113                                  15        5  ...          1197    57
# 114                                  13        5  ...          1183    53
# 115                                  14        5  ...          1158    50
# 116                                  14        5  ...          1151    54
# 117                                  16        5  ...          1145    54
# 118                                  16        5  ...          1211    54
# 119                                  15        5  ...          1236    58
# 120                                  15        5  ...          1220    65
#
#      Oklahoma  Pennsylvania  South Dakota  Wyoming  West Virginia  Utah  \
# 111       469            19             4      215             26    97
# 112       497            22             4      221             30    97
# 113       501            21             4      226             32    97
# 114       504            20             3      225             31    94
# 115       530            17             4      222             28   100
# 116       527            18             4      223             27   100
# 117       543            18             4      231             29   104
# 118       531            19             4      232             29   103
# 119       529            19             3      228             29    97
# 120       526            18             4      226             30    94
#
#      Texas  Tennessee
# 111   3525          1
# 112   3776          1
# 113   3903          1
# 114   3963          1
# 115   3894          1
# 116   4015          1
# 117   4185          1
# 118   4222          1
# 119   4245          1
# 120   4410          1
#
# [10 rows x 34 columns]

# %%
crude_oil_data.Month
#crude_oil_data['Month']
# Out:
# 0       6/1/2008
# 1       7/1/2008
# 2       8/1/2008
# 3       9/1/2008
# 4      10/1/2008
#          ...
# 116     2/1/2018
# 117     3/1/2018
# 118     4/1/2018
# 119     5/1/2018
# 120     6/1/2018
# Name: Month, Length: 121, dtype: object

# %%
crude_oil_data['Date'] = crude_oil_data['Month']

# %%
crude_oil_data
# Out:
#          Month  U.S. Crude Oil   Alabama  Alaska  Arkansas  California  \
# 0     6/1/2008             5138       21     655        17         583
# 1     7/1/2008             5177       21     640        17         586
# 2     8/1/2008             5003       21     544        17         588
# 3     9/1/2008             3974       21     681        16         587
# 4    10/1/2008             4738       21     716        17         586
# ..         ...              ...      ...     ...       ...         ...
# 116   2/1/2018            10248       17     513        14         463
# 117   3/1/2018            10461       17     512        14         462
# 118   4/1/2018            10475       17     497        14         465
# 119   5/1/2018            10443       16     496        14         464
# 120   6/1/2018            10674       16     451        14         462
#
#      Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# 0          82                                       1326
# 1          81                                       1372
# 2          82                                       1272
# 3          88                                        242
# 4          86                                        803
# ..        ...                                        ...
# 116       428                                       1704
# 117       428                                       1681
# 118       447                                       1583
# 119       447                                       1504
# 120       423                                       1658
#
#      Federal Offshore Pacific Crude Oil  Florida  ...  Ohio  Oklahoma  \
# 0                                    67        5  ...    14       186
# 1                                    61        6  ...    14       184
# 2                                    70        5  ...    14       188
# 3                                    67        5  ...    14       186
# 4                                    66        6  ...    14       185
# ..                                  ...      ...  ...   ...       ...
# 116                                  14        5  ...    54       527
# 117                                  16        5  ...    54       543
# 118                                  16        5  ...    54       531
# 119                                  15        5  ...    58       529
# 120                                  15        5  ...    65       526
#
#      Pennsylvania  South Dakota  Wyoming  West Virginia  Utah  Texas  \
# 0               8             5      144              6    60   1097
# 1               8             5      145              5    61   1111
# 2               8             5      145              6    62   1110
# 3               8             5      144              6    63   1055
# 4               8             5      145              6    64   1125
# ..            ...           ...      ...            ...   ...    ...
# 116            18             4      223             27   100   4015
# 117            18             4      231             29   104   4185
# 118            19             4      232             29   103   4222
# 119            19             3      228             29    97   4245
# 120            18             4      226             30    94   4410
#
#      Tennessee       Date
# 0            1   6/1/2008
# 1            1   7/1/2008
# 2            1   8/1/2008
# 3            1   9/1/2008
# 4            1  10/1/2008
# ..         ...        ...
# 116          1   2/1/2018
# 117          1   3/1/2018
# 118          1   4/1/2018
# 119          1   5/1/2018
# 120          1   6/1/2018
#
# [121 rows x 35 columns]

# %%
crude_oil_data.drop('Month', inplace=True, axis=1)

# %%
crude_oil_data['Date'] = pd.to_datetime(crude_oil_data['Date'])

# %%
crude_oil_data.iloc[0]['Date'].month
# Out:
# 6

# %%
crude_oil_data['Year'] = crude_oil_data['Date'].dt.year

# %%
crude_oil_data.head()
# Out:
#    U.S. Crude Oil   Alabama  Alaska  Arkansas  California  Colorado  \
# 0             5138       21     655        17         583        82
# 1             5177       21     640        17         586        81
# 2             5003       21     544        17         588        82
# 3             3974       21     681        16         587        88
# 4             4738       21     716        17         586        86
#
#    Federal Offshore Gulf of Mexico Crude Oil  \
# 0                                       1326
# 1                                       1372
# 2                                       1272
# 3                                        242
# 4                                        803
#
#    Federal Offshore Pacific Crude Oil  Florida  Idaho  ...  Oklahoma  \
# 0                                  67        5      0  ...       186
# 1                                  61        6      0  ...       184
# 2                                  70        5      0  ...       188
# 3                                  67        5      0  ...       186
# 4                                  66        6      0  ...       185
#
#    Pennsylvania  South Dakota  Wyoming  West Virginia  Utah  Texas  Tennessee  \
# 0             8             5      144              6    60   1097          1
# 1             8             5      145              5    61   1111          1
# 2             8             5      145              6    62   1110          1
# 3             8             5      144              6    63   1055          1
# 4             8             5      145              6    64   1125          1
#
#         Date  Year
# 0 2008-06-01  2008
# 1 2008-07-01  2008
# 2 2008-08-01  2008
# 3 2008-09-01  2008
# 4 2008-10-01  2008
#
# [5 rows x 35 columns]

# %%
year_data = crude_oil_data.groupby('Year', as_index= False).sum()
year_data[['Year', 'U.S. Crude Oil ']]
# Out:
#     Year  U.S. Crude Oil
# 0   2008            34211
# 1   2009            64180
# 2   2010            65741
# 3   2011            67829
# 4   2012            78007
# 5   2013            89585
# 6   2014           105064
# 7   2015           113179
# 8   2016           105970
# 9   2017           112205
# 10  2018            62296

# %%
colors = ['C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
year_data.plot.bar(x='Year', y='U.S. Crude Oil ',
                  figsize=(12,8), color = colors,
                  legend = False)

plt.ylabel('Production')
plt.title('U.S. Crude Oil Production')
# Out:
# Text(0.5, 1.0, 'U.S. Crude Oil Production')

# %%
# plot oil production over time
# create box plots per state
# create bar chart by state
